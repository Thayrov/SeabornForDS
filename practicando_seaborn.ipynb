# %% [markdown]
# <a href="https://colab.research.google.com/github/Thayrov/SeabornForDS/blob/main/practicando_seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Clase 1: Importando y traduciendo variables

# %% [markdown]
# ##Importando base de datos

# %%
import pandas as pd

# %%
pd.read_csv('credit_card.csv')
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos = pd.read_csv('credit_card.csv')
datos.head()
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# 4  16560.5000        0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# ##Traduciendo columnas e variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
dic_columnas = {
    'LIMIT_BAL': 'limite',
    'CHECKING_ACCOUNT': 'cuenta_corriente',
    'EDUCATION': 'escolaridad',
    'MARRIAGE': 'estado_civil',
    'AGE': 'edad',
    'BILL_AMT': 'valor_factura',
    'PAY_AMT': 'valor_pago',
    'DEFAULT': 'moroso'
}

# %%
tarjetas = datos.rename(columns = dic_columnas)
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022              Yes       2.University      Married    24
# 1   36132              Yes       2.University       Single    26
# 2   27099              Yes       2.University       Single    34
# 3   15055              Yes       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.cuenta_corriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
dic_cuenta = {
    'Yes': 'Si',
    'No': 'No'
}

# %%
tarjetas.cuenta_corriente = tarjetas.cuenta_corriente.map(dic_cuenta)
tarjetas.head()
# Out:
#    limite cuenta_corriente        escolaridad estado_civil  edad  \
# 0    6022               Si       2.University      Married    24
# 1   36132               Si       2.University       Single    26
# 2   27099               Si       2.University       Single    34
# 3   15055               Si       2.University      Married    37
# 4  150550               No  3.Graduate School       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.escolaridad.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_escolaridad = {
    '2.University': '2.Universidad', '3.Graduate School': '3.Pos-graduación', '1.High School' :'1.Colegio'
     }

# %%
tarjetas.escolaridad = tarjetas.escolaridad.map(dic_escolaridad)
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad      Married    24
# 1   36132               Si     2.Universidad       Single    26
# 2   27099               Si     2.Universidad       Single    34
# 3   15055               Si     2.Universidad      Married    37
# 4  150550               No  3.Pos-graduación       Single    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
tarjetas.estado_civil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_estado_civil = {
    'Married': 'Casad@',
    'Single': 'Solter@'
}

# %%
tarjetas.estado_civil = tarjetas.estado_civil.map(dic_estado_civil)
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %% [markdown]
# # Clase 2: Análisis exploratoria de variables

# %% [markdown]
# ##Importando Seaborn y análisis de distribución

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno

# %%
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso
# 0       934.0122      0.0000       1
# 1       519.3975      0.0000       1
# 2      4223.5297    457.0698       0
# 3     14522.9563    602.2000       0
# 4    124060.1253  16560.5000       0

# %%
sns.distplot(tarjetas['limite'])
# Out:
# <ipython-input-49-c84ce6169819>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tarjetas['limite'])
# <Axes: xlabel='limite', ylabel='Density'>

# %%
sns.displot(data=tarjetas, x ='limite', hue = 'escolaridad');

# %% [markdown]
# **Interpretación del gráfico:** Las personas con pos-grado tienden a tener límites de crédito mayores.

# %% [markdown]
# ##Creando variable numérica

# %%
tarjetas['iu'] = tarjetas['valor_factura'] / tarjetas['limite']

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.displot(data=tarjetas, x ='iu');

# %% [markdown]
# **Interpretación del gráfico:** Hay un público significatico que uso poco del limite que tienen disponible

# %% [markdown]
# ##Parámetros de gráficos: definiendo estilos.

# %% [markdown]
# **Colormaps de Matplotlib:** https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html

# %%
sns.set_style('darkgrid')

# %%
sns.displot(data=tarjetas, x ='limite', hue = 'escolaridad', palette='inferno_r');

# %% [markdown]
# # Clase 3: Comparando y analizando variables categóricas

# %% [markdown]
# ##Countplot, catplot y swarmplot: variables categóricas

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
sns.countplot(data=tarjetas, x ='cuenta_corriente', hue = 'moroso', palette='inferno_r');

# %%
sns.catplot(data=tarjetas, x ='estado_civil', y ='limite',hue = 'moroso', palette='inferno_r', dodge = True);

# %%
sns.swarmplot(data=tarjetas, x ='escolaridad', y ='iu', palette='inferno_r');
# Out:
# <ipython-input-78-9afb155601e6>:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(data=tarjetas, x ='escolaridad', y ='iu', palette='inferno_r');
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ##Boxplot y Violinplot

# %%
sns.boxplot(data=tarjetas, x ='escolaridad', y ='iu',hue= 'moroso', palette='inferno_r');

# %%
sns.violinplot(data=tarjetas, x ='escolaridad', y ='iu',palette='inferno_r', hue= 'moroso')
# Out:
# <Axes: xlabel='escolaridad', ylabel='iu'>

# %% [markdown]
# ##Creando y analizando variable categórica

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso        iu
# 0       934.0122      0.0000       1  0.155100
# 1       519.3975      0.0000       1  0.014375
# 2      4223.5297    457.0698       0  0.155856
# 3     14522.9563    602.2000       0  0.964660
# 4    124060.1253  16560.5000       0  0.824046

# %%
tarjetas.edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
bins = [20,30,40,50,100]
nombres = ['20-30', '30-40', '40-50', '50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['edad'], bins, labels=nombres)

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.boxplot(x='rango_edad', y='limite', data=tarjetas,palette='inferno_r', hue= 'moroso');

# %% [markdown]
# # Clase 4: Análisis de variables numéricas y regresión

# %% [markdown]
# ##Displot: variables numéricas

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.displot(data=tarjetas, x ='limite',col = 'escolaridad', kind = 'kde', hue='rango_edad');

# %% [markdown]
# ##Scatterplot y lmplot

# %%
sns.scatterplot(x='iu', y='valor_factura', data=tarjetas, hue = 'cuenta_corriente');

# %%
sns.lmplot(x='iu', y='valor_factura', data=tarjetas);

# %% [markdown]
# ##Test de hipótesis

# %%
sns.lmplot(x='iu', y='valor_factura', data=tarjetas, col='moroso');

# %%
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<sup>
#
# La distribución de los grupos moroso y no moroso es la misma

# %% [markdown]
# H<sup>alt<sup>
#
# La distribución de los grupos moroso y no moroso no es la misma

# %%
moroso = tarjetas.query("moroso == 1").valor_factura

# %%
moroso
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: valor_factura, Length: 117, dtype: float64

# %%
no_moroso = tarjetas.query("moroso == 0").valor_factura

# %%
no_moroso
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: valor_factura, Length: 1383, dtype: float64

# %%
resultado = ranksums(moroso,no_moroso)
resultado
# Out:
# RanksumsResult(statistic=-2.562530598426702, pvalue=0.010391243081223555)

# %%
print("El p_value de nuestro test es {}".format(resultado.pvalue))
# Out:
# El p_value de nuestro test es 0.010391243081223555

# %% [markdown]
# # Clase 5: Análisis conjunta de variables

# %% [markdown]
# ##Jointplot

# %%
tarjetas.head()
# Out:
#    limite cuenta_corriente       escolaridad estado_civil  edad  \
# 0    6022               Si     2.Universidad       Casad@    24
# 1   36132               Si     2.Universidad      Solter@    26
# 2   27099               Si     2.Universidad      Solter@    34
# 3   15055               Si     2.Universidad       Casad@    37
# 4  150550               No  3.Pos-graduación      Solter@    29
#
#    valor_factura  valor_pago  moroso        iu rango_edad
# 0       934.0122      0.0000       1  0.155100      20-30
# 1       519.3975      0.0000       1  0.014375      20-30
# 2      4223.5297    457.0698       0  0.155856      30-40
# 3     14522.9563    602.2000       0  0.964660      30-40
# 4    124060.1253  16560.5000       0  0.824046      20-30

# %%
sns.jointplot(x='edad', y ='limite', data = tarjetas, kind='kde', hue='moroso', palette='inferno_r');

# %% [markdown]
# ##Pairplot

# %%
pd.set_option('display.precision',2)
pd.set_option('display.float_format',lambda x:'%.2f' % x)

# %%
tarjetas.describe()
# Out:
#          limite    edad  valor_factura  valor_pago  moroso      iu
# count   1500.00 1500.00        1500.00     1500.00 1500.00 1500.00
# mean   51221.94   35.21       15459.87     1984.87    0.08    0.39
# std    39424.41    9.27       20722.58     5296.77    0.27    0.34
# min     3011.00   21.00          27.70        0.00    0.00    0.00
# 25%    18066.00   28.00        2035.59      407.01    0.00    0.05
# 50%    42154.00   33.50        7701.39      759.37    0.00    0.31
# 75%    72264.00   41.00       20671.57     1705.28    0.00    0.70
# max   210770.00   75.00      141792.51    97022.85    1.00    1.00

# %%
sns.pairplot(data =tarjetas, hue='escolaridad', palette='inferno')
